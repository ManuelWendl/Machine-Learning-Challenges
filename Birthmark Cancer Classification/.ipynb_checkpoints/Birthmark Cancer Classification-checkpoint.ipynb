# %% [markdown]
# # Birthmark Cancer Classification
# ### Motivation:
# This jupyter notebook shall provide an algorithm which detects skin cancer. The
# objectives are pictures of birthmarks. These were downloaded from the world wide largest
# skin image dataset on https://www.isic-archive.com/#!/topWithHeader/onlyHeaderTop/gallery?filter=%5B%5D.

# %% [markdown]
# ### Importing the Data

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

benign_images = []
malignant_images = []

img_size = (250, 300)

for i in range(1,16):
    for ii in range(1,81):
        img_benign = Image.open('benign_'+str(i)+'/UDA-1/img'+str(ii)+'.jpg').convert('L')
        img_malignant = Image.open('malignant_'+str(i)+'/UDA-1/img'+str(ii)+'.jpg').convert('L')
        img_benign = img_benign.resize(img_size, Image.ANTIALIAS)
        img_malignant = img_malignant.resize(img_size, Image.ANTIALIAS)
        benign_images.append(np.asarray(img_benign))
        malignant_images.append(np.asarray(img_malignant))

# %% [markdown]
# ### Preprocess Data

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.utils import shuffle
benign_images = np.array(benign_images)
malignant_images = np.array(malignant_images)

images = np.concatenate([benign_images, malignant_images])
labels = np.zeros(2400)
labels[1200:] = 1

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense, BatchNormalization, Dropout
from sklearn.model_selection import train_test_split

model = Sequential([
    Conv2D(filters=64, kernel_size=(3,3), strides=1, activation='relu',input_shape=(300, 250, 1)),
    Conv2D(filters=64, kernel_size=(3,3), strides=1, activation='relu'),
    MaxPool2D(pool_size=(2,2)),
    BatchNormalization(),
    Dropout(.2),
    Conv2D(filters=64, kernel_size=(3,3), strides=1, activation='relu'),
    Conv2D(filters=64, kernel_size=(3,3), strides=1, activation='relu'),
    MaxPool2D(pool_size=(2,2)),
    BatchNormalization(),
    Dropout(.2),
    Conv2D(filters=64, kernel_size=(3,3), strides=1, activation='relu'),
    MaxPool2D(pool_size=(2,2)),
    Conv2D(filters=64, kernel_size=(3,3), strides=1, activation='relu'),
    MaxPool2D(pool_size=(2,2)),
    Flatten(),
    Dense(200, activation='relu'),
    Dense(20, activation='relu'),
    Dense(2, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential_26"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_115 (Conv2D)          (None, 298, 248, 64)      640
# _________________________________________________________________
# conv2d_116 (Conv2D)          (None, 296, 246, 64)      36928
# _________________________________________________________________
# max_pooling2d_92 (MaxPooling (None, 148, 123, 64)      0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 148, 123, 64)      256
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 148, 123, 64)      0
# _________________________________________________________________
# conv2d_117 (Conv2D)          (None, 146, 121, 64)      36928
# _________________________________________________________________
# conv2d_118 (Conv2D)          (None, 144, 119, 64)      36928
# _________________________________________________________________
# max_pooling2d_93 (MaxPooling (None, 72, 59, 64)        0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 72, 59, 64)        256
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 72, 59, 64)        0
# _________________________________________________________________
# conv2d_119 (Conv2D)          (None, 70, 57, 64)        36928
# _________________________________________________________________
# max_pooling2d_94 (MaxPooling (None, 35, 28, 64)        0
# _________________________________________________________________
# conv2d_120 (Conv2D)          (None, 33, 26, 64)        36928
# _________________________________________________________________
# max_pooling2d_95 (MaxPooling (None, 16, 13, 64)        0
# _________________________________________________________________
# flatten_26 (Flatten)         (None, 13312)             0
# _________________________________________________________________
# dense_78 (Dense)             (None, 200)               2662600
# _________________________________________________________________
# dense_79 (Dense)             (None, 20)                4020
# _________________________________________________________________
# dense_80 (Dense)             (None, 2)                 42
# =================================================================
# Total params: 2,852,454
# Trainable params: 2,852,198
# Non-trainable params: 256
# _________________________________________________________________

# %%
import tensorflow as tf

model.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])
images = images.reshape((-1,300,250,1))

perm = np.random.permutation(2400)
images = images[perm,:,:,:]
labels = labels[perm]

train_images, test_images, train_labels, test_labels = train_test_split( images, labels, test_size=0.1)

history = model.fit(train_images, train_labels, epochs=50, batch_size=30, validation_data=(test_images, test_labels))
# Out:
# Epoch 1/50
# 72/72 [==============================] - 359s 5s/step - loss: 1.8242 - accuracy: 0.5703 - val_loss: 0.6887 - val_accuracy: 0.5542
# Epoch 2/50
# 72/72 [==============================] - 352s 5s/step - loss: 0.6313 - accuracy: 0.6647 - val_loss: 0.9155 - val_accuracy: 0.5208
# Epoch 3/50
# 72/72 [==============================] - 350s 5s/step - loss: 0.5773 - accuracy: 0.6873 - val_loss: 0.6162 - val_accuracy: 0.6875
# Epoch 4/50
# 72/72 [==============================] - 347s 5s/step - loss: 0.5192 - accuracy: 0.7541 - val_loss: 0.6215 - val_accuracy: 0.6708
# Epoch 5/50
# 72/72 [==============================] - 349s 5s/step - loss: 0.4799 - accuracy: 0.7746 - val_loss: 0.6826 - val_accuracy: 0.5833
# Epoch 6/50
# 72/72 [==============================] - 351s 5s/step - loss: 0.4893 - accuracy: 0.7664 - val_loss: 1.5679 - val_accuracy: 0.5292
# Epoch 7/50
# 72/72 [==============================] - 352s 5s/step - loss: 0.4391 - accuracy: 0.8004 - val_loss: 1.0898 - val_accuracy: 0.5625
# Epoch 8/50
# 72/72 [==============================] - 350s 5s/step - loss: 0.4148 - accuracy: 0.8082 - val_loss: 0.5976 - val_accuracy: 0.7292
# Epoch 9/50
# 72/72 [==============================] - 362s 5s/step - loss: 0.3816 - accuracy: 0.8315 - val_loss: 2.7767 - val_accuracy: 0.5250
# Epoch 10/50
# 72/72 [==============================] - 351s 5s/step - loss: 0.3243 - accuracy: 0.8607 - val_loss: 0.8929 - val_accuracy: 0.6708
# Epoch 11/50
# 72/72 [==============================] - 351s 5s/step - loss: 0.3194 - accuracy: 0.8683 - val_loss: 0.7070 - val_accuracy: 0.6000
# Epoch 12/50
# 72/72 [==============================] - 351s 5s/step - loss: 0.2544 - accuracy: 0.9067 - val_loss: 0.7861 - val_accuracy: 0.6042
# Epoch 13/50
# 72/72 [==============================] - 351s 5s/step - loss: 0.2458 - accuracy: 0.8999 - val_loss: 0.5878 - val_accuracy: 0.7083
# Epoch 14/50
# 72/72 [==============================] - 351s 5s/step - loss: 0.2044 - accuracy: 0.9220 - val_loss: 0.5973 - val_accuracy: 0.7458
# Epoch 15/50
# 72/72 [==============================] - 350s 5s/step - loss: 0.1825 - accuracy: 0.9212 - val_loss: 0.7179 - val_accuracy: 0.7083
# Epoch 16/50
# 72/72 [==============================] - 349s 5s/step - loss: 0.1530 - accuracy: 0.9390 - val_loss: 0.9066 - val_accuracy: 0.6833
# Epoch 17/50
# 72/72 [==============================] - 349s 5s/step - loss: 0.1041 - accuracy: 0.9574 - val_loss: 1.5506 - val_accuracy: 0.6333
# Epoch 18/50
# 72/72 [==============================] - 349s 5s/step - loss: 0.1125 - accuracy: 0.9496 - val_loss: 0.8544 - val_accuracy: 0.7167
# Epoch 19/50
# 72/72 [==============================] - 352s 5s/step - loss: 0.0831 - accuracy: 0.9683 - val_loss: 0.8449 - val_accuracy: 0.7167
# Epoch 20/50
# 72/72 [==============================] - 354s 5s/step - loss: 0.0817 - accuracy: 0.9696 - val_loss: 1.1450 - val_accuracy: 0.7042
# Epoch 21/50
# 72/72 [==============================] - 370s 5s/step - loss: 0.0680 - accuracy: 0.9731 - val_loss: 0.8265 - val_accuracy: 0.7542
# Epoch 22/50
# 72/72 [==============================] - 357s 5s/step - loss: 0.0752 - accuracy: 0.9696 - val_loss: 0.6529 - val_accuracy: 0.6750
# Epoch 23/50
# 72/72 [==============================] - 360s 5s/step - loss: 0.0960 - accuracy: 0.9647 - val_loss: 1.1449 - val_accuracy: 0.6458
# Epoch 24/50
# 72/72 [==============================] - 356s 5s/step - loss: 0.0912 - accuracy: 0.9596 - val_loss: 0.9540 - val_accuracy: 0.7292
# Epoch 25/50
# 72/72 [==============================] - 359s 5s/step - loss: 0.0663 - accuracy: 0.9745 - val_loss: 1.8159 - val_accuracy: 0.6583
# Epoch 26/50
# 72/72 [==============================] - 358s 5s/step - loss: 0.1052 - accuracy: 0.9647 - val_loss: 1.0436 - val_accuracy: 0.7500
# Epoch 27/50
# 72/72 [==============================] - 368s 5s/step - loss: 0.0151 - accuracy: 0.9932 - val_loss: 0.8005 - val_accuracy: 0.7125
# Epoch 28/50
# 72/72 [==============================] - 360s 5s/step - loss: 0.0184 - accuracy: 0.9912 - val_loss: 10.1263 - val_accuracy: 0.5000
# Epoch 29/50
# 72/72 [==============================] - 361s 5s/step - loss: 0.0621 - accuracy: 0.9735 - val_loss: 1.0989 - val_accuracy: 0.7542
# Epoch 30/50
# 72/72 [==============================] - 360s 5s/step - loss: 0.0632 - accuracy: 0.9749 - val_loss: 1.3503 - val_accuracy: 0.7208
# Epoch 31/50
# 72/72 [==============================] - 370s 5s/step - loss: 0.0456 - accuracy: 0.9859 - val_loss: 1.8179 - val_accuracy: 0.7125
# Epoch 32/50
# 72/72 [==============================] - 363s 5s/step - loss: 0.0144 - accuracy: 0.9957 - val_loss: 1.2853 - val_accuracy: 0.7500
# Epoch 33/50
# 72/72 [==============================] - 354s 5s/step - loss: 0.0928 - accuracy: 0.9756 - val_loss: 1.1823 - val_accuracy: 0.6417
# Epoch 34/50
# 72/72 [==============================] - 350s 5s/step - loss: 0.0351 - accuracy: 0.9880 - val_loss: 1.2198 - val_accuracy: 0.7042
# Epoch 35/50
# 72/72 [==============================] - 351s 5s/step - loss: 0.0295 - accuracy: 0.9934 - val_loss: 1.0625 - val_accuracy: 0.7875
# Epoch 36/50
# 72/72 [==============================] - 350s 5s/step - loss: 0.0093 - accuracy: 0.9974 - val_loss: 0.9665 - val_accuracy: 0.8000
# Epoch 37/50
# 72/72 [==============================] - 351s 5s/step - loss: 0.0105 - accuracy: 0.9981 - val_loss: 1.4246 - val_accuracy: 0.6458
# Epoch 38/50
# 72/72 [==============================] - 354s 5s/step - loss: 0.0301 - accuracy: 0.9891 - val_loss: 1.3830 - val_accuracy: 0.6917
# Epoch 39/50
# 72/72 [==============================] - 350s 5s/step - loss: 0.0324 - accuracy: 0.9916 - val_loss: 2.2053 - val_accuracy: 0.6417
# Epoch 40/50
# 72/72 [==============================] - 351s 5s/step - loss: 0.0341 - accuracy: 0.9882 - val_loss: 1.2197 - val_accuracy: 0.7000
# Epoch 41/50
# 72/72 [==============================] - 350s 5s/step - loss: 0.0294 - accuracy: 0.9925 - val_loss: 1.7342 - val_accuracy: 0.7375
# Epoch 42/50
# 72/72 [==============================] - 355s 5s/step - loss: 0.0183 - accuracy: 0.9949 - val_loss: 1.2600 - val_accuracy: 0.7000
# Epoch 43/50
# 72/72 [==============================] - 348s 5s/step - loss: 0.0179 - accuracy: 0.9957 - val_loss: 0.9522 - val_accuracy: 0.8042
# Epoch 44/50
# 72/72 [==============================] - 347s 5s/step - loss: 0.0153 - accuracy: 0.9943 - val_loss: 1.1309 - val_accuracy: 0.7833
# Epoch 45/50
# 72/72 [==============================] - 350s 5s/step - loss: 0.0222 - accuracy: 0.9954 - val_loss: 1.2191 - val_accuracy: 0.7667
# Epoch 46/50
# 72/72 [==============================] - 355s 5s/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 1.1487 - val_accuracy: 0.7875
# Epoch 47/50
# 72/72 [==============================] - 350s 5s/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 1.3026 - val_accuracy: 0.7792
# Epoch 48/50
# 72/72 [==============================] - 353s 5s/step - loss: 0.0048 - accuracy: 0.9992 - val_loss: 1.3858 - val_accuracy: 0.7667
# Epoch 49/50
# 72/72 [==============================] - 355s 5s/step - loss: 0.0032 - accuracy: 0.9994 - val_loss: 1.2852 - val_accuracy: 0.7667
# Epoch 50/50
# 72/72 [==============================] - 349s 5s/step - loss: 7.5796e-04 - accuracy: 1.0000 - val_loss: 1.4629 - val_accuracy: 0.7833

# %%
plt.figure()
plt.title('accuracy')
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['train-accuracy','validation-accuracy'])
plt.show()

# %% [markdown]
# ### Save Model

# %%
model.save('model_VGG16_architecture.h5')

# %% [markdown]
# ### Visualisation of test cases

# %%
predict = model.predict(test_images)

plt.figure(figsize=(40,40))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.imshow(test_images[i,:,:,:].reshape(300,250), cmap='gray')
    plt.title('True: '+str(int(test_labels[i]))+'  Prediction: '+str(np.argmax(predict[i,:]))+' Propability: '+str(np.max(predict[i,:])))

# %%
from sklearn.metrics import confusion_matrix

pred = np.zeros(len(predict))
for i in range(len(predict)):
    pred[i] = np.argmax(predict[i])

print('Confusion Matrix:')
print(confusion_matrix(test_labels,pred))
# Out:
# Confusion Matrix:
# [[101  19]
#  [ 33  87]]
